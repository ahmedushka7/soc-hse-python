# %% [markdown]
# # Контрольная работа

# %%
import scipy.stats as sts
import numpy as np

# %% [markdown]
# ## Правила игры
#
# - контрольная состоит из 3-х задач, баллы за задание указаны в скобках
# - у вас есть одна пара (1 ч. 20 мин.) на решение
# - можно пользоваться материалами с лекций и семинаров
# - решение отправлять на почту `midiukin@mail.ru` (нужно прикрепить .ipynb файл)

# %% [markdown]
# ## 1. Намешано (25 баллов)
#
# Мирон любит мешать не только рифмы и панчи, но и распределения! И вот сейчас две трети данных идут в смесь из экспоненциального распределения с параметром $\lambda = 1$, а остальная треть из стандартного нормального $\mathcal{N}(0, 1)$. Как это часто бывает, Мирон сначала намешал, а потом чёт подумал-подумал и всё Славе отдал. И теперь у Славы проблема со свойствами намешанного распределения.
#
# Сгенерируйте выборку из распределения Мирона и помогите Славе оценить математическое ожидание.

# %%
## Ваш код

# %% [markdown]
# ## 2. Осьминог Пауль (35 баллов)
#
# <img src="../images/test_paul.jpeg" width="500" align="left">

# %% [markdown]
# В $2008$ году проходил международный турнир по футболу. Тогда разлетелась история про осьминога Пауля (также его прозвали осьминогом-пророком), который магическим образом предсказывал исходы матчей. В аквариум к животному помещали $2$ миски с едой, на каждой из которых были флаги стран, которым предстояло играть следующий матч. Считалось, что из какой миски начнет есть осьминог, та страна и победит.
#
# Таким образом, Паулю удалось отгадать $4$ из $6$ матчей. Но у меня закрались сомнения, что осьминог действительно был волшебным, поэтому я прошу у вас помощи ответить на несколько статистических вопросов:
#
# - __а)__ У вас есть выборка из $1$ и $0$ ($1$, если осьминог отгадал матч и $0$, если не отгадал). Каким распределением лучше всего описать эту выборку? (**5 баллов**)
#
# - __б)__ Предположим, что мы верим в то, что осьминог выбирает миски наугад. Чему тогда равен параметр выбранного вами распределения? (**5 баллов**)
#
# - __в)__ Сгенерируйте выборку размера $n$ ($n = 10, 100, 1000$) из выбранного вами распределения и при условии, что осьминог выбирает миски наугад. Затем посчитайте выборочную оценку для параметра и сравните ее с той, которая есть с фактической выборкой (то есть с реальной выборкой, где осьминог угадал $4$ из $6$ матчей). (**10 баллов**)
#
# - __г)__ Какой вывод на основе пункта "в" можно сделать? Есть ли у осьминога способности? Почему да/нет? Распишите как можно подробнее (**15 баллов**)

# %%
fact_sample = [1, 0, 1, 1, 1, 0, 0]

### Ваш код

# %% [markdown]
# ## 3. Три Топора
#
# <img src="../images/test_7.png" width="300" align="left">

# %% [markdown]
# Витя – очень азартный человек, поэтому приехав в Сочи, первым делом он пошел не в горы, а в казино. Больше всего Вите нравится играть в автоматы, когда ты дергаешь за рычаг и собираешь комбинацию из одинаковых элементов.
#
# Предположим, Витя играет в автомат, где есть $3$ барабана, на каждом из которых может выпасть $1$, $2$ либо $7$. При этом вероятность выпадения $1$ – $0.5$, выпадения $2$ – $0.3$, выпадения $7$ – $0.2$.
#
# Даня очень любит цифру $7$, поэтому крутит барабан, пока не получит $777$. Цена одной игры (одной прокрутки барабанов) – $100$ руб. Пусть $X$ – случайная величина, сколько денег потратил Даня в казино. Чему равно $E(X)$? То есть сколько в среднем денег Даня будет тратить, играя в казино до тех пор, пока не получит три топора (комбинацию $777$).

# %%
## Ваш код
