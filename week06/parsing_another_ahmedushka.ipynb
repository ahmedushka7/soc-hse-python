# %% [markdown]
# ## Парсинг (скрепинг)

# %% [markdown]
# ## Классический парсинг

# %% [markdown]
# ### Парсинг
#
# Парсинг – извлечение неструктурированных данных из интернета.
#
# <center>
#     <img src="images/download.png" width="550px">
# </center>

# %% [markdown]
# ### На чем пишутся сайты?

# %% [markdown]
# **HTML (HyperText Markup Language)**  — это такой же язык разметки как Markdown или LaTeX. Он является стандартным для написания различных сайтов. Если открыть абсолютно любой сайт, нажать на правую кнопку мышки, а после нажать `View page source`, то перед вами предстанет HTML скелет этого сайта.
#
# Можно открыть html-код стартовой яндекса, найти в нём новость из топа и немного её изменить. Понятное дело, что вы так меняете html-страничку только на своём компьютере (клиенте). На сервере яндекса остаётся исходная версия. Когда вы обновите страничку все правки исчезнут.

# %% [markdown]
# <img src="images/yandex_html.png">

# %% [markdown]
# ### Теги
#
# Команды в HTML называются **тегами**. HTML-страница это ни что иное, как набор вложенных тегов. Можно заметить, например, следующие теги:
#
# * \<title\> – заголовок страницы
# * \<h1\>…\<h6\> – заголовки разных уровней
# * \<p\> – абзац (paragraph)
# * \<div\> – выделения фрагмента документа с целью изменения вида содержимого
# * \<table\> – прорисовка таблицы
# * \<tr\> – разделитель для строк в таблице
# * \<td\> – разделитель для столбцов в таблице
# * \<b\> – устанавливает жирное начертание шрифта
#
# Обычно команда <...> открывает тег, а </...> закрывает его. Все, что находится между этими двумя командами, подчиняется правилу, которое диктует тег. Например, все, что находится между \<p\> и \</p\> — это отдельный абзац.

# %% [markdown]
# ### Пример
#
# Например, HTML-древо страницы может выглядеть вот так:
#
# ```html
# <html>
# <head> Заголовок </head>
# <body>
#     <div>
#         Первый кусок текста со своими свойствами
#     </div>
#     <div>
#         Второй кусок текста
#             <b>
#                 Третий, жирный кусок
#             </b>
#     </div>
#     Четвёртый кусок текста
# </body>
# </html>
# ```

# %% [markdown]
# ### html ~ tree
#
# Теги образуют своеобразное дерево с корнем в теге <html> и разбивают страницу на разные логические кусочки. У каждого тега есть свои потомки (дети) — те теги, которые вложены в него и свои родители.
#
# Можно работать с этим html как с текстом, а можно как с деревом. Обход этого дерева и есть парсинг веб-страницы. Мы всего лишь будем находить нужные нам узлы среди всего этого разнообразия и забирать из них информацию!

# %% [markdown]
# ```
# <html>
# <head> Заголовок </head>
# <body>
#     <div>
#         Первый кусок текста со своими свойствами
#     </div>
#     <div>
#         Второй кусок текста
#             <b>
#                 Третий, жирный кусок
#             </b>
#     </div>
#     Четвёртый кусок текста
# </body>
# </html>
# ```

# %% [markdown]
# <center>
# <img src="images/tree.png" width="450">

# %% [markdown]
# ### Качаем цены на книги
#
# Давайте соберем информацию с сайта о [книгах](http://books.toscrape.com). Этот сайт специально создан, чтобы тренироваться парсить на нем.
#
# Получать html позволяет модуль `requests`, он не входит в стандартуную библиотеку *python*. Сделав запрос, мы видим код 200. Этот код, означает, что все прошло успешно. Вы наверняка встречали ошибку 404 в своей жизни. Что означает каждая ошибка можно почитать [тут](https://ru.wikipedia.org/wiki/Список_кодов_состояния_HTTP).

# %%
url = 'http://books.toscrape.com/'
response = requests.get(url)
print(response)
print(response.status_code)
# Out:
# <Response [200]>
# 200

# %%
requests.get('http://books.toscrape.com/hse')
# Out:
# <Response [404]>

# %% [markdown]
# ### Что получили?
#
# Внутри response лежит html страница, которую и надо спарсить.

# %%
response.content[:1000]
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->\n    <head>\n        <title>\n    All products | Books to Scrape - Sandbox\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n        <meta name="created" content="24th Jun 2016 09:29" />\n        <meta name="description" content="" />\n        <meta name="viewport" content="width=device-width" />\n        <meta name="robots" content="NOARCHIVE,NOCACHE" />\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link rel="shortcut icon" href="static/oscar/favicon.'

# %% [markdown]
# ### BeautifulSoup
#
# Выглядит не очень. Мы говорили, что удобнее работать с деревом.
#
# <img align="center" src="images/alisa.jpg" height="200" width="200">
#
# Пакет **[`bs4`](https://www.crummy.com/software/BeautifulSoup/)**, a.k.a **BeautifulSoup** был назван в честь стишка про красивый суп из Алисы в стране чудес. Эта совершенно волшебная библиотека, которая из сырого и необработанного HTML (или XML) кода страницы выдаст вам структурированный массив данных, по которому очень удобно искать необходимые теги, классы, атрибуты, тексты и прочие элементы веб страниц.
#
# > Пакет под названием `BeautifulSoup` — скорее всего, не то, что вам нужно. Это третья версия (*Beautiful Soup 3*), а мы будем использовать четвертую. Так что нам нужен пакет `beautifulsoup4`. Чтобы было совсем весело, при импорте нужно указывать другое название пакета — `bs4`, а импортировать функцию под названием `BeautifulSoup`.

# %%
# !pip install bs4
from bs4 import BeautifulSoup

# распарсили страничку в дерево 
tree = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# Внутри переменной `tree` теперь лежит дерево из тегов, по которому мы можем совершенно спокойно бродить.

# %%
tree.head.title
# Out:
# <title>
#     All products | Books to Scrape - Sandbox
# </title>

# %%
tree.head.title.text.strip()
# Out:
# 'All products | Books to Scrape - Sandbox'

# %% [markdown]
# Можно вытащить из того места, куда мы забрели, текст с помощью метода `text`.

# %%
tree.html.head.title.text
# Out:
# '\n    All products | Books to Scrape - Sandbox\n'

# %% [markdown]
# С текстом можно работать классическими питоновскими методами. Например, можно избавиться от лишних отступов.

# %%
tree.html.head.title.text.strip()
# Out:
# 'All products | Books to Scrape - Sandbox'

# %% [markdown]
# Более того, зная адрес элемента, мы сразу можем найти его. Например, вот так в коде страницы мы можем найти где именно для каждой книги лежит основная информация. Видно, что она находится внутри тега `article`, для которого прописан класс `product_pod` (грубо говоря, в html класс задаёт оформление соотвествующего кусочка страницы).
#
# Вытащим инфу о книге из этого тега.

# %% [markdown]
# <p class="first">
#     text
# </p>
#
# <p class="second">
#     another text
# </p>
#
# p class="first":
#     color: blue
#
# p class="second":
#     color: red

# %%
books = tree.find_all('article', {'class': 'product_pod'})

# %%
len(books)
# Out:
# 20

# %%
type(books)
# Out:
# bs4.element.ResultSet

# %% [markdown]
# Полученный после поиска объект также обладает структурой bs4. Поэтому можно продолжить искать нужные нам объекты уже в нём.

# %%
type(books[0])
# Out:
# bs4.element.Tag

# %%
books[0]
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
books[0].find_all('p', {'class': 'price_color'})
# Out:
# [<p class="price_color">£51.77</p>]

# %%
books[0].find('p', {'class': 'price_color'})
# Out:
# <p class="price_color">£51.77</p>

# %%
books[0].find('p', {'class': 'price_color'}).text
# Out:
# '£51.77'

# %% [markdown]
# Обратите внимание, что для поиска есть как минимум два метода: `find` и `find_all`. Если несколько элементов на странице обладают указанным адресом, то метод `find` вернёт только самый первый. Чтобы найти все элементы с таким адресом, нужно использовать метод `find_all`. На выход будет выдан список.
#
# Кроме содержимого у тегов часто есть атрибуты. Например, у названия книги есть атрибуты `title` и `href`, их тоже можно вытащить.

# %%
books[0].h3.a
# Out:
# <a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a>

# %%
books[0].h3.a.text
# Out:
# 'A Light in the ...'

# %%
books[0].h3.a.get('href')
# Out:
# 'a-light-in-the-attic_1000/index.html'

# %%
books[0].h3.a.get('title')
# Out:
# 'A Light in the Attic'

# %% [markdown]
# А ещё по этим атрибутам можно искать интересующие нас кусочки страницы.

# %%
tree.find_all('a', {'title': 'A Light in the Attic'})
# Out:
# [<a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a>]

# %% [markdown]
# Собственно говоря, это всё.
#
# Обратите внимание, что на сайте все книги лежат на разных страничках. Если попробовать потыкать их, можно заметить, что в ссылке будет меняться атрибут `page`. Значит, если мы хотим собрать все книги, надо создать кучу ссылок с разным `page` внутри цикла. Когда качаешь данные с более сложных сайтов, в ссылке часто есть огромное количество атрибутов, которые регулируют выдачу.
#
#
# Давайте запишем весь код для сбора книг в виде функции. На вход она будет принимать номер странички, которую надо скачать.

# %%
import requests
from bs4 import BeautifulSoup

# %%
# получаем html
url = 'http://books.toscrape.com/'
response = requests.get(url)

# распарсили страничку в дерево 
tree = BeautifulSoup(response.content, 'html.parser')

# достаем все книжки
books = tree.find_all('article', {'class': 'product_pod'})

# %%
books[0].find('p', {'class': 'price_color'}).text
books[0].h3.a.get('href')
books[0].h3.a.get('title')

books[1].find('p', {'class': 'price_color'}).text
books[1].h3.a.get('href')
books[1].h3.a.get('title')

books[2].find('p', {'class': 'price_color'}).text
books[2].h3.a.get('href')
books[2].h3.a.get('title')

# %%
data = []
for book in books:
    data.append(
        {
            'name': book.h3.a.get('title'),
            'price': book.find('p', {'class': 'price_color'}).text,
            'link': book.h3.a.get('href'),
        }
    )

# %%
data[0]
# Out:
# {'name': 'A Light in the Attic',
#  'price': '£51.77',
#  'link': 'catalogue/a-light-in-the-attic_1000/index.html'}

# %%
p = 4
url = f'http://books.toscrape.com/catalogue/page-{p}.html'
url
# Out:
# 'http://books.toscrape.com/catalogue/page-4.html'

# %%
def get_page(p):
    
    # изготовили ссылку
    url = f'http://books.toscrape.com/catalogue/page-{p}.html'
    
    # сходили по ней
    response = requests.get(url)
    
    # построили дерево 
    tree = BeautifulSoup(response.content, 'html.parser')
    
    # нашли в нём всё самое интересное
    books = tree.find_all('article', {'class' : 'product_pod'})
    
    infa = []
    
    for book in books:        
        infa.append({'price': book.find('p', {'class': 'price_color'}).text,
                     'href': book.h3.a.get('href'),
                     'title': book.h3.a.get('title')})
                     
    return infa

# %%
get_page(p=5)
# Out:
# [{'price': '£13.61',
#   'href': 'princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html',
#   'title': 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)'},
#  {'price': '£13.34',
#   'href': 'princess-between-worlds-wide-awake-princess-5_919/index.html',
#   'title': 'Princess Between Worlds (Wide-Awake Princess #5)'},
#  {'price': '£18.97',
#   'href': 'pop-gun-war-volume-1-gift_918/index.html',
#   'title': 'Pop Gun War, Volume 1: Gift'},
#  {'price': '£36.28',
#   'href': 'political-suicide-missteps-peccadilloes-bad-calls-backroom-hijinx-sordid-pasts-rotten-breaks-and-just-plain-dumb-mistakes-in-the-annals-of-american-politics_917/index.html',
#   'title': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics'},
#  {'price': '£10.16', 'href': 'patience_916/index.html', 'title': 'Patience'},
#  {'price': '£15.44',
#   'href': 'outcast-vol-1-a-darkness-surrounds-him-outcast-1_915/index.html',
#   'title': 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)'},
#  {'price': '£48.41',
#   'href': 'orange-the-complete-collection-1-orange-the-complete-collection-1_914/index.html',
#   'title': 'orange: The Complete Collection 1 (orange: The Complete Collection #1)'},
#  {'price': '£46.35',
#   'href': 'online-marketing-for-busy-authors-a-step-by-step-guide_913/index.html',
#   'title': 'Online Marketing for Busy Authors: A Step-By-Step Guide'},
#  {'price': '£14.07',
#   'href': 'on-a-midnight-clear_912/index.html',
#   'title': 'On a Midnight Clear'},
#  {'price': '£14.86',
#   'href': 'obsidian-lux-1_911/index.html',
#   'title': 'Obsidian (Lux #1)'},
#  {'price': '£33.37',
#   'href': 'my-paris-kitchen-recipes-and-stories_910/index.html',
#   'title': 'My Paris Kitchen: Recipes and Stories'},
#  {'price': '£56.40',
#   'href': 'masks-and-shadows_909/index.html',
#   'title': 'Masks and Shadows'},
#  {'price': '£14.02',
#   'href': 'mama-tried-traditional-italian-cooking-for-the-screwed-crude-vegan-and-tattooed_908/index.html',
#   'title': 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed'},
#  {'price': '£46.91',
#   'href': 'lumberjanes-vol-2-friendship-to-the-max-lumberjanes-5-8_907/index.html',
#   'title': 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)'},
#  {'price': '£45.61',
#   'href': 'lumberjanes-vol-1-beware-the-kitten-holy-lumberjanes-1-4_906/index.html',
#   'title': 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)'},
#  {'price': '£19.92',
#   'href': 'lumberjanes-vol-3-a-terrible-plan-lumberjanes-9-12_905/index.html',
#   'title': 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)'},
#  {'price': '£40.11',
#   'href': 'layered-baking-building-and-styling-spectacular-cakes_904/index.html',
#   'title': 'Layered: Baking, Building, and Styling Spectacular Cakes'},
#  {'price': '£53.90',
#   'href': 'judo-seven-steps-to-black-belt-an-introductory-guide-for-beginners_903/index.html',
#   'title': 'Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)'},
#  {'price': '£35.67', 'href': 'join_902/index.html', 'title': 'Join'},
#  {'price': '£22.00',
#   'href': 'in-the-country-we-love-my-family-divided_901/index.html',
#   'title': 'In the Country We Love: My Family Divided'}]

# %% [markdown]
# Осталось только пройтись по всем страничкам от page-1 до page-50 циклом и данные у нас в кармане.

# %%
# !pip install tqdm

# %%
get_page(1)
get_page(2)
get_page(3)
get_page(4)
get_page(5)

# %%
x = []

# %%
x.append([1, 2, 3])

# %%
x.extend([1, 2, 3])

# %%
x
# Out:
# [1, 2, 3]

# %%
from time import sleep
from tqdm import tqdm

infa = []

for p in tqdm(range(1, 50 + 1)):
    infa.extend(get_page(p))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:38<00:00,  1.31it/s]

# %%
# !pip install pandas

# %%
import pandas as pd

df = pd.DataFrame(infa)
print(df.shape)
df.head()
# Out:
# (1000, 3)
#     price                                               href  \
# 0  £51.77               a-light-in-the-attic_1000/index.html
# 1  £53.74                  tipping-the-velvet_999/index.html
# 2  £50.10                          soumission_998/index.html
# 3  £47.82                       sharp-objects_997/index.html
# 4  £54.23  sapiens-a-brief-history-of-humankind_996/index...
#
#                                    title
# 0                   A Light in the Attic
# 1                     Tipping the Velvet
# 2                             Soumission
# 3                          Sharp Objects
# 4  Sapiens: A Brief History of Humankind

# %%
df['price'] = df['price'].str.replace("£", '').astype(float)

# %%
# сохраняем в файлик
df.to_csv('data.csv', index=False)

# %%
# !pip install matplotlib

# %%
df['price'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Кстати говоря, если перейти по ссылке в саму книгу, там о ней будет куча дополнительной информации. Можно пройтись по всем ссылкам и выкачать себе по ним дополнительную информацию.

# %% [markdown]
# ## Сервер злится

# %% [markdown]
# ### Что делать, если сервер разозлился
#
# * Вы решили собрать себе немного данных
# * Сервер не в восторге от бомбардировки автоматическими запросами
# * Error 403, 404, 504, $\ldots$
# * Капча, требования зарегистрироваться
# * Заботливые сообщения, что с вашего устройства обнаружен подозрительный трафик
#
# <center>
#     <img src="images/doge.jpg" width="450">
# </center>

# %% [markdown]
# ### Быть терпеливым
#
# * Слишком частые запросы раздражают сервер
# * Ставьте между ними временные задержки

# %%
import time
time.sleep(2.4)

# %%
from tqdm import tqdm

infa = []

for p in tqdm(range(1, 50 + 1)):
    infa.extend(get_page(p))
    time.sleep(3)
# Out:
#  16%|███████████████████▏                                                                                                    | 8/50 [00:23<02:05,  2.98s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [86], in <cell line: 5>()
#       5 for p in tqdm(range(1, 50 + 1)):
#       6     infa.extend(get_page(p))
# ----> 7     time.sleep(2)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Быть похожим на человека
#
# Запрос нормального человека через браузер выглядит так:
#
# <center>
# <img src="images/browser_get.png" width="600">
#
# С ним на сервер попадает куча информации! Запрос от питона выглядит так:
#
# <center>
# <img src="images/python_get.jpg" width="250">
#
# Заметили разницу?  Очевидно, что нашему скромному запросу не тягаться с таким обилием мета-информации, которое передается при запросе из обычного браузера. К счастью, никто нам не мешает притвориться человечными и пустить пыль в глаза сервера при помощи генерации фейкового юзер-агента. Библиотека [fake-useragent.](https://pypi.org/project/fake-useragent/) при вызове метода из различных кусочков будет генерировать рандомное сочетание операционной системы, спецификаций и версии браузера, которые можно передавать в запрос.

# %%
# !pip install fake_useragent
from fake_useragent import UserAgent
UserAgent().chrome
# Out:
# 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.93 Safari/537.36'

# %% [markdown]
# Например, https://knowyourmeme.com/ не захочет пускать к себе python и выдаст ошибку 403. Она выдается сервером, если он доступен и способен обрабатывать запросы, но по некоторым личным причинам отказывается это делать. А если сгенерировать User-Agent, вопросов у сервера не возникнет.

# %%
url = 'https://knowyourmeme.com/'

response = requests.get(url)
response
# Out:
# <Response [403]>

# %%
response = requests.get(url, headers={'User-Agent': UserAgent().chrome})
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Общаться через посредников
#
# <center>
# <img src="images/proxy.jpeg" width="400">

# %% [markdown]
# Посмотрим на свой ip-адрес без прокси.

# %%
r = requests.get('https://httpbin.org/ip')
print(r.json())
# Out:
# {'origin': '95.12.127.194'}

# %% [markdown]
# А теперь попробуем посмотреть, что будет если подключить прокси.

# %%
proxies = {
    'http': '201.218.158.79:999',
#     'https': '182.53.206.47:47592'
}

r = requests.get('https://httpbin.org/ip', proxies=proxies)

print(r.json())
# Out:
# {'origin': '95.12.127.194'}

# %% [markdown]
# Запрос работал немного подольше, ip адрес сменился. Большая часть проксей, которые вы найдёте работают криво. Иногда запрос идёт очень долго и выгоднее сбросить его и попробовать другую проксю. Это можно настроить опцией `timeout`.  Например, так если сервер не будет отвечать секунду, код упадёт.

# %%
from requests import ConnectTimeout

# %%
import requests
requests.get('http://www.google.com', timeout=0.01)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/site-packages/urllib3/connectionpool.py:398, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397     else:
# --> 398         conn.request(method, url, **httplib_request_kw)
#     400 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     401 # legitimately able to close the connection after sending a valid response.
#     402 # With this behaviour, the received response is still readable.
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/site-packages/urllib3/connection.py:239, in HTTPConnection.request(self, method, url, body, headers)
#     238     headers["User-Agent"] = _get_default_user_agent()
# --> 239 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/http/client.py:1256, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1255 """Send a complete request to the server."""
# -> 1256 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/http/client.py:1302, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1301     body = _encode(body, 'body')
# -> 1302 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/http/client.py:1251, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1250     raise CannotSendHeader()
# -> 1251 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/http/client.py:1011, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1010 del self._buffer[:]
# -> 1011 self.send(msg)
#    1013 if message_body is not None:
#    1014
#    1015     # create a consistent interface to message_body
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/http/client.py:951, in HTTPConnection.send(self, data)
#     950 if self.auto_open:
# --> 951     self.connect()
#     952 else:
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/site-packages/urllib3/connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/site-packages/urllib3/connection.py:179, in HTTPConnection._new_conn(self)
#     178 except SocketTimeout:
# --> 179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#     185 except SocketError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPConnection object at 0x7fd86dc0a520>, 'Connection to www.google.com timed out. (connect timeout=0.01)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/site-packages/urllib3/connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='www.google.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7fd86dc0a520>, 'Connection to www.google.com timed out. (connect timeout=0.01)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Input In [270], in <cell line: 2>()
#       1 import requests
# ----> 2 requests.get('http://www.google.com', timeout=0.01)
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/envs/python-course-mts/lib/python3.8/site-packages/requests/adapters.py:507, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     504 if isinstance(e.reason, ConnectTimeoutError):
#     505     # TODO: Remove this in 3.0.0: see #2811
#     506     if not isinstance(e.reason, NewConnectionError):
# --> 507         raise ConnectTimeout(e, request=request)
#     509 if isinstance(e.reason, ResponseError):
#     510     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPConnectionPool(host='www.google.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7fd86dc0a520>, 'Connection to www.google.com timed out. (connect timeout=0.01)'))

# %% [markdown]
# У requests есть довольно много разных интересных примочек. Посмотреть на них можно в [гайде из документации.](https://requests.readthedocs.io/en/master/user/advanced/)
#
#
# __Где можно попытаться раздобыть списки прокси:__
#
# * https://qna.habr.com/q/591069
# * https://getfreeproxylists.blogspot.com/
# * Большая часть бесплатных прокси обычно не работает. Пишите парсер, который будет собирать списки из проксей и пытаться применить их.

# %% [markdown]
# ## TOR
#
# <center>
# <img src="images/tor.jpg" width="600">
#
# Можно попытаться обходить злые сервера через тор. Есть несколько способов, но мы про это говорить не будем. Лучше подробно почитать в статье на [Хабре](https://habr.com/ru/company/ods/blog/346632/).

# %% [markdown]
# ## Совместить всё?
#
# 1. Начните с малого
# 2. Если продолжает банить, накидывайте новые примочки
# 3. Каждая новая примочка бьёт по скорости
# 4. [Разные примочки для requests](http://docs.python-requests.org/en/v0.10.6/user/advanced/)

# %% [markdown]
# ## API

# %% [markdown]
# ### Рефлексия
#
# Давайте посмотрим на картинку и поймем чем мы занимались до этого. Несложно догадаться какой вариант может быть лучше.
#
# <center>
#     <img src="images/wo_api.png" width="500px">

# %% [markdown]
# ### Парето улучшение
#
# Хотелось бы ходить сразу в базу данных. От этого выгоднее всем:
# 1. Мы получаем очень быстро информацию в структурированном виде.
# 2. Сервер не страдает от наших запросов.
#
# <center>
#     <img src="images/with_api.png" width="500px">

# %% [markdown]
# ### API
#
# __API (Application Programming Interface__ — инструмент, который позволяет взамодействовать с чем-либо. Похоже на пульт, у вас есть набор кнопок, которые что-то делают. Перед тем как парсить что-то попробуйте найти API, тогда ваша жизнь облгечится в разы.
#
# Примеры:
#
# * [Контактовский API](https://vk.com/dev/methods)
# * [API twitter](https://developer.twitter.com/en/docs.html)
# * [API youtube](https://developers.google.com/youtube/v3/)
# * [API google maps](https://developers.google.com/maps/documentation/)
# * [Aviasales](https://www.aviasales.ru/API)
# * [Yandex Translate](https://yandex.ru/dev/translate/)

# %%
N = 70
N * (N - 1) * 30
# Out:
# 144900

# %% [markdown]
# ### Vk API
#
# Социальная сеть — это тонны различной полезной информации, которую можно использовать для чего угодно. [В документации](https://vk.com/dev/manuals) очень подробно описано как можно работать с vk API.
#
# Но для начала к API нужно получить доступ.
#
# Для работы с API нужно создать свое приложение. Для этого переходим по [ссылке](http://vk.com/editapp?act=create) и проходимся по необходимым шагам:
#
# <img align="center" src="images/app_creation_1.png" width="500">

# %% [markdown]
# После подтверждения своей личности по номеру телефона, попадаем на страницу свежесозданного приложения
#
# <img align="center" src="images/app_creation_2.png" width="500">

# %% [markdown]
# Слева нам будем доступна вкладка с настройками, перейдя в неё мы увидим все необходимые нам для работы с приложением параметры:
# <img align="center" src="images/app_creation_3.png" width="500">
#
# Отсюда в качестве токена можно забрать сервисный ключ доступа. Для работы с частью методов API этого вполне достаточно (обычно в заголовке такого метода стоит соответствующая пометка). Иногда нужны дополнительные доступы. Для того, чтобы получить их, необходимо сделать ещё пару странных манипуляций:

# %% [markdown]
# Переходим по ссылке вида (на месте звездочек должен стоять ID созданного вами приложения):
#
# > https://oauth.vk.com/authorize?client_id=**********&scope=8198&redirect_uri=https://oauth.vk.com/blank.html&display=page&v=5.16&response_type=token
#
# В итоге по этому запросу будет сформирована ссылка следующего вида:
# > https://oauth.vk.com/blank.html#access_token=*****&expires_in=86400&user_id=******
#
# Первый набор знаков — `access token`, т.е. маркер доступа. Вторая цифра (`expires_in=`) время работы маркера доступа в секундах (одни сутки). По истечению суток нужно будет получить новый маркер доступа. Последняя цифра (`user_id=`) ваш ID Вконтакте. Нам в дальнейшем понадобится маркер доступа. Для удобства сохраним его в отдельном файле или экспортируем в глобальную область видимости. В целях безопасности ваших данных не стоит нигде светить токенами и тем более выкладывать их в открытый доступ. __Так можно и аккаунта случайно лишиться.__
#
# Обратите внимание на ссылку, по которой мы делали запрос на предоставление токена. Внутри неё находится странный параметр `scope=8198.` Это мы просим доступ к конкретным разделам. Подробнее познакомиться с взаимно-однозначным соответствием между числами и правами можно [в документации.](https://vk.com/dev/permissions) Например, если мы хотим получить доступ к друзьям, фото и стенам, мы подставим в scope цифру 2+4++8192=8198.

# %% [markdown]
# ### Храним токен правильно
#
# Токен – это способ аудентификации, как логин + пароль. Токен нельзя хранить в файлах с кодом. Есть 2 варианта:
# 1. Хранить в файле и никуда его не выкладывать. Добавить в .gitignore.
# 2. Хранить в переменных окружения.

# %%
with open('token.txt') as f:
    TOKEN = f.read()

# %% [markdown]
# ### Как пользоваться API
#
# Использование API однотипно, если научитесь пользоваться Vk API, то научитесь пользоваться и другими. Что нужно сделать?
#
# 1. Получить токен.
# 2. Выбрать метод, который хотите использовать.
# 3. Выбрать аргументы (опции), которые этот метод принимает.
# 4. Сформировать ссылку:
#     * `?` – разделитель, после которого указываются аргументы
#     * `&` – разделитель между аргументами
# ```python
# main_url + method + '?' + arg1 + '&' + arg2 + ...
# ```
# 5. Сделать HTTP запрос. Мы уже его делали, когда использовали *requests*.

# %% [markdown]
# ### Пробуем!

# %%
myid = '73614108'
version = '5.131'
method = 'users.get'
main_url = 'https://api.vk.com/method/'

url = main_url + method + '?' + f'v={version}' + '&' + f'access_token={TOKEN}' + '&' + f'user_ids={myid},210700286'

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
data = response.json()

# %%
type(data)
# Out:
# dict

# %%
data
# Out:
# {'response': [{'id': 73614108,
#    'first_name': 'Ахмед',
#    'last_name': 'Зарманбетов',
#    'can_access_closed': True,
#    'is_closed': True},
#   {'id': 210700286,
#    'first_name': 'Lindsey',
#    'last_name': 'Stirling',
#    'can_access_closed': True,
#    'is_closed': False}]}

# %% [markdown]
# ### Json
#
# В ответ на наш запрос API отдает *json* с информацией. *json* – формат данных, который очень похож на *python dict*. Он более строгий:
# * можно использовать только двойные кавычки
# * строго с пробелами
# * строго с запятыми
# * True/False с маленькой буквы

# %%
import json

# %%
# dict -> string json
d = {'a': 5, 'b': [1, 2, 3], 'c': True}
json.dumps(d)
# Out:
# '{"a": 5, "b": [1, 2, 3], "c": true}'

# %%
# string json -> dict
j = '{"a": 5, "b": [1, 2, 3]}'
json.loads(j)
# Out:
# {'a': 5, 'b': [1, 2, 3]}

# %%
d = {'a': 5, 'b': [1, 2, 3]}
with open('simple.json', 'w') as f:
    json.dump(d, f)

# %%
with open('simple.json') as f:
    j = json.load(f)
print(j)
# Out:
# {'a': 5, 'b': [1, 2, 3]}

# %% [markdown]
# ### Смотрим что получили

# %%
data['response']
# Out:
# [{'id': 73614108,
#   'first_name': 'Ахмед',
#   'last_name': 'Зарманбетов',
#   'can_access_closed': True,
#   'is_closed': True},
#  {'id': 210700286,
#   'first_name': 'Lindsey',
#   'last_name': 'Stirling',
#   'can_access_closed': True,
#   'is_closed': False}]

# %%
pd.DataFrame(data['response'])
# Out:
#           id first_name    last_name  can_access_closed  is_closed
# 0   73614108      Ахмед  Зарманбетов               True       True
# 1  210700286    Lindsey     Stirling               True      False

# %%
response.json()['response'][0]['first_name']

# %% [markdown]
# ### Удобная функция
#
# Давайте напишем функцию, которая поможет нам делать запросы удобно и быстро.

# %%
from typing import Dict, Any, List


def vk_api(method: str, params: Dict[str, Any]) -> List[Dict]:
    main_url = 'https://api.vk.com/method/'
    
    default_params = {
        'v': '5.131',
        'access_token': TOKEN,
    }
    
    final_params = {**default_params, **params}
    
    string_params = "&".join([f"{k}={v}" for k, v in final_params.items()])
    url = main_url + method + '?' + string_params
    
    response = requests.get(url)
    data = response.json()
    
    return data['response']

# %%
params = {
    'user_ids': '210700286,73614108',
    'fields': 'photo_200,verified,bdate',
}

data = vk_api(
    method='users.get',
    params=params,
)

# %%
params = {
    'user_id': '73614108',
#     'fields': 'photo_200,verified,bdate',
}

data = vk_api(
    method='friends.get',
    params=params,
)

# %% [markdown]
# ### Собираем лайки группы

# %%
params = {
    'owner_id': -32370614,
    'count': 100,
}

data = vk_api(
    method='wall.get',
    params=params,
)

# %%
data
# Out:
# {'count': 48380,
#  'items': [{'id': 6892212,
#    'from_id': -32370614,
#    'owner_id': -32370614,
#    'date': 1665584220,
#    'marked_as_ads': 0,
#    'is_favorite': False,
#    'post_type': 'post',
#    'text': '',
#    'is_pinned': 1,
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1665559121,
#       'id': 457975092,
#       'owner_id': -32370614,
#       'access_key': '48112130843fa10576',
#       'post_id': 6892212,
#       'sizes': [{'height': 60,
#         'url': 'https://sun6-22.userapi.com/impg/lzl051pc3Q-oyWFgG_0xuBpgiMuzwhoSrr36mA/tlmTDqc0p7s.jpg?size=75x60&quality=95&sign=cd0702925fe2d4985431c6e35bd0fe92&c_uniq_tag=cjfGqykb3mDr-WqrCC9--Tc4DzKZHV_gIJKEQ-S-WEA&type=album',
#         'type': 's',
#         'width': 75},
#        {'height': 104,
#         'url': 'https://sun6-22.userapi.com/impg/lzl051pc3Q-oyWFgG_0xuBpgiMuzwhoSrr36mA/tlmTDqc0p7s.jpg?size=130x104&quality=95&sign=50b8f14f46d306ccd4a5119b3012adc0&c_uniq_tag=Bl7zcZYfbCIEQ4NvTrjFTDnRdHi3T0gYUwb3ky_6z3g&type=album',
#         'type': 'm',
#         'width': 130},
#        {'height': 483,
#         'url': 'https://sun6-22.userapi.com/impg/lzl051pc3Q-oyWFgG_0xuBpgiMuzwhoSrr36mA/tlmTDqc0p7s.jpg?size=604x483&quality=95&sign=1f1105edb335c8384588620ab3f272df&c_uniq_tag=9cCJYGHJj1sjFFsyWFLUQNqlQQt9gLIY53mb2batGWk&type=album',
#         'type': 'x',
#         'width': 604},
#        {'height': 646,
#         'url': 'https://sun6-22.userapi.com/impg/lzl051pc3Q-oyWFgG_0xuBpgiMuzwhoSrr36mA/tlmTDqc0p7s.jpg?size=807x646&quality=95&sign=13ad45366a00957906e1c94044cbe20e&c_uniq_tag=JDo0l4Rxt0C4ceiWT9cxcKWx516KH83uwdsmgy5Po4Q&type=album',
#         'type': 'y',
#         'width': 807},
#        {'height': 1024,
#         'url': 'https://sun6-22.userapi.com/impg/lzl051pc3Q-oyWFgG_0xuBpgiMuzwhoSrr36mA/tlmTDqc0p7s.jpg?size=1280x1024&quality=95&sign=e8d8f99fa6ae0c1c806e596fce923387&c_uniq_tag=qSmcAUnrjv08k60Vkp-B5BdY_wRfT0JLjWehen-qdc8&type=album',
#         'type': 'z',
#         'width': 1280},
#        {'height': 1080,
#         'url': 'https://sun6-22.userapi.com/impg/lzl051pc3Q-oyWFgG_0xuBpgiMuzwhoSrr36mA/tlmTDqc0p7s.jpg?size=1350x1080&quality=95&sign=7b8a18ad3eb2254c39660a7d927f989d&c_uniq_tag=N3VoqK8vogtAk0LFoPG40Yrus4XSq6D52mRl_j3GwXQ&type=album',
#         'type': 'w',
#         'width': 1350},
#        {'height': 104,
#         'url': 'https://sun6-22.userapi.com/impg/lzl051pc3Q-oyWFgG_0xuBpgiMuzwhoSrr36mA/tlmTDqc0p7s.jpg?size=130x104&quality=95&sign=50b8f14f46d306ccd4a5119b3012adc0&c_uniq_tag=Bl7zcZYfbCIEQ4NvTrjFTDnRdHi3T0gYUwb3ky_6z3g&type=album',
#         'type': 'o',
#         'width': 130},
#        {'height': 160,
#         'url': 'https://sun6-22.userapi.com/impg/lzl051pc3Q-oyWFgG_0xuBpgiMuzwhoSrr36mA/tlmTDqc0p7s.jpg?size=200x160&quality=95&sign=67e84a25f7e44ff39a31743f5bfb13f5&c_uniq_tag=Vt4kc3CxLD31W6tymBqJ_pLjWwU4ERs-_B4Uh5nE4_M&type=album',
#         'type': 'p',
#         'width': 200},
#        {'height': 256,
#         'url': 'https://sun6-22.userapi.com/impg/lzl051pc3Q-oyWFgG_0xuBpgiMuzwhoSrr36mA/tlmTDqc0p7s.jpg?size=320x256&quality=95&sign=637e607a6436989efec32dd453eafc4c&c_uniq_tag=QtZCngneLqbfabO60ufgTtDjFVT7rBiFz1oScaKXiwU&type=album',
#         'type': 'q',
#         'width': 320},
#        {'height': 408,
#         'url': 'https://sun6-22.userapi.com/impg/lzl051pc3Q-oyWFgG_0xuBpgiMuzwhoSrr36mA/tlmTDqc0p7s.jpg?size=510x408&quality=95&sign=2879b5142b1ce178e132d61e69b098b0&c_uniq_tag=Vjebi-UpaXeyxM7Bwzb-5Ud0PcETCm3IhsgfQ1MMURM&type=album',
#         'type': 'r',
#         'width': 510}],
#       'text': '',
#       'user_id': 100,
#       'has_tags': False}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'can_post': 1, 'count': 93, 'groups_can_post': True},
#    'likes': {'can_like': 1, 'count': 3495, 'user_likes': 0, 'can_publish': 1},
#    'reposts': {'count': 404, 'user_reposted': 0},
#    'views': {'count': 145121},
#    'donut': {'is_donut': False},
#    'short_text_rate': 0.8,
#    'hash': 'ZmVn12CicjwFJhKDlvj5Ps9_DXc'},
#   {'id': 6892563,
#    'from_id': -32370614,
#    'owner_id': -32370614,
#    'date': 1665595020,
#    'marked_as_ads': 0,
#    'is_favorite': False,
#    'post_type': 'post',
#    'text': 'Нет ничего важнее семьи',
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1665495333,
#       'id': 457974963,
#       'owner_id': -32370614,
#       'access_key': '67d81e914b74c9f2c1',
#       'sizes': [{'height': 75,
#         'url': 'https://sun6-22.userapi.com/impg/0mjahNkqmCCikdQitYnf2LNmflbMe6DAuBY0Nw/I2mOHNn70BU.jpg?size=75x75&quality=95&sign=dd228d7c4e3b4cdde4788bcf6526a6b7&c_uniq_tag=jw5GjXMdP3Ht5Gq1XppNrt99FY9hPlUOyFUii67rH2I&type=album',
#         'type': 's',
#         'width': 75},
#        {'height': 130,
#         'url': 'https://sun6-22.userapi.com/impg/0mjahNkqmCCikdQitYnf2LNmflbMe6DAuBY0Nw/I2mOHNn70BU.jpg?size=130x130&quality=95&sign=8eccd7f1eecceb46d478be8497110d1f&c_uniq_tag=VOfDMSUo4t63f0z19Zr8X72tcSxjtW27O9PuO_aC6ss&type=album',
#         'type': 'm',
#         'width': 130},
#        {'height': 604,
#         'url': 'https://sun6-22.userapi.com/impg/0mjahNkqmCCikdQitYnf2LNmflbMe6DAuBY0Nw/I2mOHNn70BU.jpg?size=604x604&quality=95&sign=2f0233f2d32942d4773771395b78fc5d&c_uniq_tag=eRBfUwsImFFSPSEoOVEvhngPipzcOQMOKynTQasvVP8&type=album',
#         'type': 'x',
#         'width': 604},
#        {'height': 807,
#         'url': 'https://sun6-22.userapi.com/impg/0mjahNkqmCCikdQitYnf2LNmflbMe6DAuBY0Nw/I2mOHNn70BU.jpg?size=807x807&quality=95&sign=d670ef503ba6c04de29d4c590e3e5ffd&c_uniq_tag=3idEy9Zb_JFsDdBo6neKFYnz4DzRH3Q-rcGm9cTpR7g&type=album',
#         'type': 'y',
#         'width': 807},
#        {'height': 1080,
#         'url': 'https://sun6-22.userapi.com/impg/0mjahNkqmCCikdQitYnf2LNmflbMe6DAuBY0Nw/I2mOHNn70BU.jpg?size=1080x1080&quality=95&sign=00e4b83f1842666d14854e7a005e68e3&c_uniq_tag=NeSx1rGks6bce-EmPm36JGL_gFunHYLOS6XPJtzH_G8&type=album',
#         'type': 'z',
#         'width': 1080},
#        {'height': 130,
#         'url': 'https://sun6-22.userapi.com/impg/0mjahNkqmCCikdQitYnf2LNmflbMe6DAuBY0Nw/I2mOHNn70BU.jpg?size=130x130&quality=95&sign=8eccd7f1eecceb46d478be8497110d1f&c_uniq_tag=VOfDMSUo4t63f0z19Zr8X72tcSxjtW27O9PuO_aC6ss&type=album',
#         'type': 'o',
#         'width': 130},
#        {'height': 200,
#         'url': 'https://sun6-22.userapi.com/impg/0mjahNkqmCCikdQitYnf2LNmflbMe6DAuBY0Nw/I2mOHNn70BU.jpg?size=200x200&quality=95&sign=e03916cea785131790e64dd52cc89c79&c_uniq_tag=RzD68xsv-0qNwbhQchLLL7BKHCYWuV4T-FcT9MFHjrg&type=album',
#         'type': 'p',
#         'width': 200},
#        {'height': 320,
#         'url': 'https://sun6-22.userapi.com/impg/0mjahNkqmCCikdQitYnf2LNmflbMe6DAuBY0Nw/I2mOHNn70BU.jpg?size=320x320&quality=95&sign=80a425c496918aac8aab4b2ab2b1c8a0&c_uniq_tag=3yyREygW6N5aoBFlqF4UTGePcUijZtEUSU1AvbY2NCI&type=album',
#         'type': 'q',
#         'width': 320},
#        {'height': 510,
#         'url': 'https://sun6-22.userapi.com/impg/0mjahNkqmCCikdQitYnf2LNmflbMe6DAuBY0Nw/I2mOHNn70BU.jpg?size=510x510&quality=95&sign=ba2a105dbf569e5098a9600c615efa6c&c_uniq_tag=jZjlOYZ7K1bwX7yD_iQfAMy8qRszOSjCfIjyaxmZGBc&type=album',
#         'type': 'r',
#         'width': 510}],
#       'text': '',
#       'user_id': 100,
#       'has_tags': False}},
#     {'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1665495333,
#       'id': 457974964,
#       'owner_id': -32370614,
#       'access_key': '9fee645c2ec631bbd2',
#       'sizes': [{'height': 75,
#         'url': 'https://sun6-22.userapi.com/impg/BXueCHfC-RGRjjH3FgUJZamR9bodlQ4k-JIfJQ/MfuXpUVwYWo.jpg?size=75x75&quality=95&sign=1f8a3e66d721c9fb06792811cb5145a0&c_uniq_tag=UDXDAx3Vq1V1roDH1cCeQ7c3e2JxGN6ZnfXyVBVEZeI&type=album',
#         'type': 's',
#         'width': 75},
#        {'height': 130,
#         'url': 'https://sun6-22.userapi.com/impg/BXueCHfC-RGRjjH3FgUJZamR9bodlQ4k-JIfJQ/MfuXpUVwYWo.jpg?size=130x130&quality=95&sign=2c062aa8eea40a3a1bbe0196e8b203bf&c_uniq_tag=eET8Hok1v2Ta_4MRN-BFbCFwe9vraFspx6o0y1stXPw&type=album',
#         'type': 'm',
#         'width': 130},
#        {'height': 604,
#         'url': 'https://sun6-22.userapi.com/impg/BXueCHfC-RGRjjH3FgUJZamR9bodlQ4k-JIfJQ/MfuXpUVwYWo.jpg?size=604x604&quality=95&sign=7e152ded9078d44baddde1908b5aa5b2&c_uniq_tag=OGhGggaRq1Z8xQOga69sqhcHkKJ1GyTwNDwvSIEQwgw&type=album',
#         'type': 'x',
#         'width': 604},
#        {'height': 807,
#         'url': 'https://sun6-22.userapi.com/impg/BXueCHfC-RGRjjH3FgUJZamR9bodlQ4k-JIfJQ/MfuXpUVwYWo.jpg?size
type=album',
#         'type': 'q',
#         'width': 320},
#        {'height': 340,
#         'url': 'https://sun6-21.userapi.com/impg/JwGXfF6cfQ_soyN29_Gjlg-n3WEAreVtkJzshw/fXuxUR21ZkQ.jpg?size=510x340&quality=95&crop=170,0,1020,680&sign=37ec58dc4144ca3bac0ce0428d44ff0c&c_uniq_tag=zvA3Jlbc3HfoNLUxv-Ec1k1E8RNfgKq4OoJrZTGBNfs&type=album',
#         'type': 'r',
#         'width': 510}],
#       'text': '',
#       'user_id': 100,
#       'has_tags': False}},
#     {'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1665494605,
#       'id': 457974956,
#       'owner_id': -32370614,
#       'access_key': '26b9d506ab818a2beb',
#       'sizes': [{'height': 37,
#         'url': 'https://sun6-22.userapi.com/impg/gzSypFwl1HFV_JDFqnacO5B6IJNrd28RzihUXw/a4dnqX0Yyxk.jpg?size=75x37&quality=95&sign=340237c1bf6d5235634649f9b09bff7e&c_uniq_tag=9ZhrUPMIuCHUOWTDOGzyit1S8tHQbdj_QnZJarvte1g&type=album',
#         'type': 's',
#         'width': 75},
#        {'height': 65,
#         'url': 'https://sun6-22.userapi.com/impg/gzSypFwl1HFV_JDFqnacO5B6IJNrd28RzihUXw/a4dnqX0Yyxk.jpg?size=130x65&quality=95&sign=9fb2e11e16247afe673966dbc3ae6b03&c_uniq_tag=t0Q2M2fcsT-B3FopqY_2bTN2GNRQ8ApzzWPv17UcHZg&type=album',
#         'type': 'm',
#         'width': 130},
#        {'height': 302,
#         'url': 'https://sun6-22.userapi.com/impg/gzSypFwl1HFV_JDFqnacO5B6IJNrd28RzihUXw/a4dnqX0Yyxk.jpg?size=604x302&quality=95&sign=2a01998995e9a82744f747a541093695&c_uniq_tag=h_gHitMJz-S-lFWMFzFbIwChxMziR-FTEi6bZUzVGwM&type=album',
#         'type': 'x',
#         'width': 604},
#        {'height': 403,
#         'url': 'https://sun6-22.userapi.com/impg/gzSypFwl1HFV_JDFqnacO5B6IJNrd28RzihUXw/a4dnqX0Yyxk.jpg?size=807x403&quality=95&sign=97cfaf595830ce1be3522f8d8dc76575&c_uniq_tag=D89-gQPhw1RAId_UOQkgi0qlqggwn0m9Qo_UuFnLPh8&type=album',
#         'type': 'y',
#         'width': 807},
#        {'height': 640,
#         'url': 'https://sun6-22.userapi.com/impg/gzSypFwl1HFV_JDFqnacO5B6IJNrd28RzihUXw/a4dnqX0Yyxk.jpg?size=1280x640&quality=95&sign=4e907037ae245dfc39826609c23dbd4a&c_uniq_tag=YeFTGGOF8NfvAY-sLN5PVMc3VMgO4Vg2BgBzyGbXAEY&type=album',
#         'type': 'z',
#         'width': 1280},
#        {'height': 680,
#         'url': 'https://sun6-22.userapi.com/impg/gzSypFwl1HFV_JDFqnacO5B6IJNrd28RzihUXw/a4dnqX0Yyxk.jpg?size=1360x680&quality=95&sign=ab6419feef2ec50a72a02bcfa4e2847f&c_uniq_tag=qv3NWdh211YlrY9UgrLF12gGcBSKNs4bmKfjI-ssCfc&type=album',
#         'type': 'w',
#         'width': 1360},
#        {'height': 87,
#         'url': 'https://sun6-22.userapi.com/impg/gzSypFwl1HFV_JDFqnacO5B6IJNrd28RzihUXw/a4dnqX0Yyxk.jpg?size=130x87&quality=95&crop=172,0,1016,680&sign=c6536fc8605e536ade370e0057bc1859&c_uniq_tag=b7veeWUYFU2RVP126DGsaqa_ljzJ1BwYoqn3ECYfyCQ&type=album',
#         'type': 'o',
#         'width': 130},
#        {'height': 133,
#         'url': 'https://sun6-22.userapi.com/impg/gzSypFwl1HFV_JDFqnacO5B6IJNrd28RzihUXw/a4dnqX0Yyxk.jpg?size=200x133&quality=95&crop=168,0,1023,680&sign=a1bc6409054339fe32b0d425b036e674&c_uniq_tag=5001kWM-f3-go9orGmWLXLpw09Zo-MCEmycKSix9vaU&type=album',
#         'type': 'p',
#         'width': 200},
#        {'height': 213,
#         'url': 'https://sun6-22.userapi.com/impg/gzSypFwl1HFV_JDFqnacO5B6IJNrd28RzihUXw/a4dnqX0Yyxk.jpg?size=320x213&quality=95&crop=169,0,1022,680&sign=d41739cc8a221db27d22d340c33d6a71&c_uniq_tag=vFiJaD2hNODT36k3B8UIlknyqSCnUNZdIXzgYUJIeFU&type=album',
#         'type': 'q',
#         'width': 320},
#        {'height': 340,
#         'url': 'https://sun6-22.userapi.com/impg/gzSypFwl1HFV_JDFqnacO5B6IJNrd28RzihUXw/a4dnqX0Yyxk.jpg?size=510x340&quality=95&crop=170,0,1020,680&sign=979754e450472cec9af2b7585cfd4421&c_uniq_tag=hwNUiDC6cg2JNRO5AUxHxkHexZYRjRf3ofTmnkm0o7w&type=album',
#         'type': 'r',
#         'width': 510}],
#       'text': '',
#       'user_id': 100,
#       'has_tags': False}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'can_post': 1, 'count': 41, 'groups_can_post': True},
#    'likes': {'can_like': 1, 'count': 1113, 'user_likes': 0, 'can_publish': 1},
#    'reposts': {'count': 87, 'user_reposted': 0},
#    'views': {'count': 75113},
#    'donut': {'is_donut': False},
#    'short_text_rate': 0.8,
#    'carousel_offset': 0,
#    'hash': 'JRjNCRob3txP1coqdYQRdCsFNF8'},
#   {'id': 6892344,
#    'from_id': -32370614,
#    'owner_id': -32370614,
#    'date': 1665587820,
#    'marked_as_ads': 0,
#    'is_favorite': False,
#    'post_type': 'post',
#    'text': 'ЛЫСЫЙ КАЧОК ВЕРНЁТСЯ: Хирам Гарсия, продюсер двух частей «Джуманджи» с Дуэйном Скалой Джонсоном, уверяет, что третья часть - это лишь вопрос времени.',
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1665550749,
#       'id': 457975066,
#       'owner_id': -32370614,
#       'access_key': '6e7f0b33ddcde28de7',
#       'sizes': [{'height': 75,
#         'url': 'https://sun6-20.userapi.com/impg/2juDJCXf5dJxYVlq-iuO8--mEV26Ebhwpyy00A/S5Chr0eQLQg.jpg?size=75x75&quality=95&sign=4ef30bbf24f612c70b111baeecef4350&c_uniq_tag=8J5aKtLv9c_RhXVWLan4JFlmwfazaHYqVssoFyu71Nc&type=album',
#         'type': 's',
#         'width': 75},
#        {'height': 130,
#         'url': 'https://sun6-20.userapi.com/impg/2juDJCXf5dJxYVlq-iuO8--mEV26Ebhwpyy00A/S5Chr0eQLQg.jpg?size=130x130&quality=95&sign=3dd31c76613f761ec52acee4326264fa&c_uniq_tag=1uwMUQuZtsMuoWkLQBsGrQgoZZsP8fgyxEgCm3ZegmA&type=album',
#         'type': 'm',
#         'width': 130},
#        {'height': 604,
#         'url': 'https://sun6-20.userapi.com/impg/2juDJCXf5dJxYVlq-iuO8--mEV26Ebhwpyy00A/S5Chr0eQLQg.jpg?size=604x604&quality=95&sign=ef7a40dd501bcb0a2e11a952590f59de&c_uniq_tag=02gjl7vpY4-coorQFCkNjNR8WAJuQthD9f4xijqREYg&type=album',
#         'type': 'x',
#         'width': 604},
#        {'height': 807,
#         'url': 'https://sun6-20.userapi.com/impg/2juDJCXf5dJxYVlq-iuO8--mEV26Ebhwpyy00A/S5Chr0eQLQg.jpg?size=807x807&quality=95&sign=4d29cb9f9d9cbfb769149950a28818c1&c_uniq_tag=VRDheCl9_zokjheb3-7-rfrCZbGRrQd7UNQSfWZO7ME&type=album',
#         'type': 'y',
#         'width': 807},
#        {'height': 1080,
#         'url': 'https://sun6-20.userapi.com/impg/2juDJCXf5dJxYVlq-iuO8--mEV26Ebhwpyy00A/S5Chr0eQLQg.jpg?size=1080x1080&quality=95&sign=7f6031cebf9f6d6e373c434cf0ec7127&c_uniq_tag=nKUeGK9_poJ50wMqnOg5WhEdP9z_Z5qnRxZ4pEVCulo&type=album',
#         'type': 'z',
#         'width': 1080},
#        {'height': 130,
#         'url': 'https://sun6-20.userapi.com/impg/2juDJCXf5dJxYVlq-iuO8--mEV26Ebhwpyy00A/S5Chr0eQLQg.jpg?size=130x130&quality=95&sign=3dd31c76613f761ec52acee4326264fa&c_uniq_tag=1uwMUQuZtsMuoWkLQBsGrQgoZZsP8fgyxEgCm3ZegmA&type=album',
#         'type': 'o',
#         'width': 130},
#        {'height': 200,
#         'url': 'https://sun6-20.userapi.com/impg/2juDJCXf5dJxYVlq-iuO8--mEV26Ebhwpyy00A/S5Chr0eQLQg.jpg?size=200x200&quality=95&sign=7117cc33479af4c3255d375a5ead5e86&c_uniq_tag=CYcRU0fV8GeZpHXen8_jqChsnGoB9Sp1AbILdA_8ZvM&type=album',
#         'type': 'p',
#         'width': 200},
#        {'height': 320,
#         'url': 'https://sun6-20.userapi.com/impg/2juDJCXf5dJxYVlq-iuO8--mEV26Ebhwpyy00A/S5Chr0eQLQg.jpg?size=320x320&quality=95&sign=1f1a06c558ad5f0354c318b1dac0efb4&c_uniq_tag=KhMrB3Gu8R4ekKW0ST7lx0TbLUue0Zqd2eAB2jjc6Vg&type=album',
#         'type': 'q',
#         'width': 320},
#        {'height': 510,
#         'url': 'https://sun6-20.userapi.com/impg/2juDJCXf5dJxYVlq-iuO8--mEV26Ebhwpyy00A/S5Chr0eQLQg.jpg?size=510x510&quality=95&sign=12c732e22307466039d6fcb2f553b4a5&c_uniq_tag=TqWrCvkvK4T8LA2NszWLZlcN71ODqDXarN7tqtwDTqA&type=album',
#         'type': 'r',
#         'width': 510}],
#       'text': '',
#       'user_id': 100,
#       'has_tags': False}},
#     {'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1665550749,
#       'id': 457975067,
#       'owner_id': -32370614,
#       'access_key': '83321be0a92ed7bca9',
#       'sizes': [{'height': 75,
# ...
#         'type': 'o',
#         'width': 130},
#        {'height': 160,
#         'url': 'https://sun6-23.userapi.com/impg/68MeU8gLdAjf2c-zxczKBUKrLGZIrXZ_V1J2aQ/rrG9FfFh6_4.jpg?size=200x160&quality=95&sign=e44dae4ca9b858eefd88d75421e82f10&c_uniq_tag=PD9EpGTV4MCC71d3o-RTtiG0EzLHw1IS1u8VuwabMaA&type=album',
#         'type': 'p',
#         'width': 200},
#        {'height': 256,
#         'url': 'https://sun6-23.userapi.com/impg/68MeU8gLdAjf2c-zxczKBUKrLGZIrXZ_V1J2aQ/rrG9FfFh6_4.jpg?size=320x256&quality=95&sign=38f8c1c2a75afda22d95f80fd2eeb921&c_uniq_tag=ifoj7x4Jv7ZEWIdt-5SeUWUki0bXgsCegFZpRrWgzAo&type=album',
#         'type': 'q',
#         'width': 320},
#        {'height': 408,
#         'url': 'https://sun6-23.userapi.com/impg/68MeU8gLdAjf2c-zxczKBUKrLGZIrXZ_V1J2aQ/rrG9FfFh6_4.jpg?size=510x408&quality=95&sign=a3f282a7029043028eed223f89a9eb9b&c_uniq_tag=ZJ-Q4Dt5ieVl9TuCjdlkHR1tIwKMZN1iM89E1K_ZSJo&type=album',
#         'type': 'r',
#         'width': 510}],
#       'text': '',
#       'user_id': 100,
#       'has_tags': False}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'can_post': 1, 'count': 21, 'groups_can_post': True},
#    'likes': {'can_like': 1, 'count': 1604, 'user_likes': 0, 'can_publish': 1},
#    'reposts': {'count': 95, 'user_reposted': 0},
#    'views': {'count': 155161},
#    'donut': {'is_donut': False},
#    'short_text_rate': 0.8,
#    'carousel_offset': 0,
#    'hash': 'xIRdkXOUGyZ3FEc6GxmFmQ67VW0'},
#   {'id': 6882736,
#    'from_id': -32370614,
#    'owner_id': -32370614,
#    'date': 1665166620,
#    'marked_as_ads': 0,
#    'is_favorite': False,
#    'post_type': 'post',
#    'text': 'ВЕЗУНЧИКИ: Как рассказал Дэвид Эйр, узкий круг лиц из поклонников творчества режиссёра увидели режиссерскую версию «Отряда самоубийц» 2016 года.\n\nПо их отзывам, фильм идет 143 минуты и имеет абсолютно другой монтаж, даже в плане последовательности сцен.',
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1665133309,
#       'id': 457974259,
#       'owner_id': -32370614,
#       'access_key': '8680e71ddc4474833a',
#       'sizes': [{'height': 75,
#         'url': 'https://sun6-20.userapi.com/impg/TJlcWI8TYfnyfqui9alNu08EteCAMeTeyC6uqQ/iz3dHEnv4IY.jpg?size=60x75&quality=95&sign=58a17b5e5345f6d31dd3558cab880935&c_uniq_tag=UuiyAwoLR9nkyVNTfvop4qe6ooHyMnu80k_075zxvN8&type=album',
#         'type': 's',
#         'width': 60},
#        {'height': 130,
#         'url': 'https://sun6-20.userapi.com/impg/TJlcWI8TYfnyfqui9alNu08EteCAMeTeyC6uqQ/iz3dHEnv4IY.jpg?size=104x130&quality=95&sign=645fcc9d5b5fab94c4d26bb7f7a77cdf&c_uniq_tag=qeuv538uCNZQBA4zoRWQSyxv_aocTJPJT8AWGBK5o7k&type=album',
#         'type': 'm',
#         'width': 104},
#        {'height': 604,
#         'url': 'https://sun6-20.userapi.com/impg/TJlcWI8TYfnyfqui9alNu08EteCAMeTeyC6uqQ/iz3dHEnv4IY.jpg?size=483x604&quality=95&sign=037e31e8d2f4b4b67936de017fbf5d1b&c_uniq_tag=m8_1xo9NLAR4mAtL0srb4K5pEraatmrbneezSylY3Qs&type=album',
#         'type': 'x',
#         'width': 483},
#        {'height': 807,
#         'url': 'https://sun6-20.userapi.com/impg/TJlcWI8TYfnyfqui9alNu08EteCAMeTeyC6uqQ/iz3dHEnv4IY.jpg?size=646x807&quality=95&sign=a150f856980e86d2f60eae4e450a3416&c_uniq_tag=byDmMUlrWwfIFtrTeZJXQmhlEz6Z7ometfJIXvIZXiE&type=album',
#         'type': 'y',
#         'width': 646},
#        {'height': 1080,
#         'url': 'https://sun6-20.userapi.com/impg/TJlcWI8TYfnyfqui9alNu08EteCAMeTeyC6uqQ/iz3dHEnv4IY.jpg?size=864x1080&quality=95&sign=a4a2728d9b7b4a33dea687da046c6ef9&c_uniq_tag=WwXPhl9CHXv1JhVAq_Zv2KoMrgG5uYoePs3pgs_rU8M&type=album',
#         'type': 'z',
#         'width': 864},
#        {'height': 1350,
#         'url': 'https://sun6-20.userapi.com/impg/TJlcWI8TYfnyfqui9alNu08EteCAMeTeyC6uqQ/iz3dHEnv4IY.jpg?size

#         'url': 'https://sun6-20.userapi.com/impg/0h3dFz04Zoxb7PPrPCeMv-CCQfLrUmTP7-i-qA/rFBYekL_N9w.jpg?size=320x400&quality=95&sign=1664851369a2447ae5a9ee5abf2796f8&c_uniq_tag=gHY8p3ksrfwX1gucKR3o__vDmMXUoZX_f2AsP81fkbs&type=album',
#         'type': 'q',
#         'width': 320},
#        {'height': 637,
#         'url': 'https://sun6-20.userapi.com/impg/0h3dFz04Zoxb7PPrPCeMv-CCQfLrUmTP7-i-qA/rFBYekL_N9w.jpg?size=510x637&quality=95&sign=c74744fcdd8387921876a7245f94380e&c_uniq_tag=2SwT7pXRYlKrrFC3fBpN5s_yc2ZahnYXcde-lLfVgRc&type=album',
#         'type': 'r',
#         'width': 510}],
#       'text': '',
#       'user_id': 100,
#       'has_tags': False}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'can_post': 1, 'count': 41, 'groups_can_post': True},
#    'likes': {'can_like': 1, 'count': 2741, 'user_likes': 0, 'can_publish': 1},
#    'reposts': {'count': 90, 'user_reposted': 0},
#    'views': {'count': 156824},
#    'donut': {'is_donut': False},
#    'short_text_rate': 0.8,
#    'carousel_offset': 0,
#    'hash': 'B7h52oYnGhFGoIzVfKAYne1rgtU'},
#   {'id': 6882572,
#    'from_id': -32370614,
#    'owner_id': -32370614,
#    'date': 1665163920,
#    'marked_as_ads': 0,
#    'is_favorite': False,
#    'post_type': 'post',
#    'text': 'БЕЗУМИЕ И КАМЕО: Бенедикт Камбербэтч и Элизабет Олсен на съемках, как оказалось, лучшего проекта Четвёртой Фазы КВМ',
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1665084338,
#       'id': 457974180,
#       'owner_id': -32370614,
#       'access_key': 'd994e767732e1e7de2',
#       'sizes': [{'height': 75,
#         'url': 'https://sun6-23.userapi.com/impg/PmK3iDWVrGaMuG800Lsq6t9L_SmlqfbwC0eAUQ/AQn5av6NpBU.jpg?size=60x75&quality=95&sign=7739b87164ff99b1f76be3c306956757&c_uniq_tag=CxzFRG1b_y2iwXWak3pWI2DJmXSPFCb52881mDH1KcQ&type=album',
#         'type': 's',
#         'width': 60},
#        {'height': 130,
#         'url': 'https://sun6-23.userapi.com/impg/PmK3iDWVrGaMuG800Lsq6t9L_SmlqfbwC0eAUQ/AQn5av6NpBU.jpg?size=104x130&quality=95&sign=d41ca9027eea5abab6a0e1286fbb16a6&c_uniq_tag=ArEd9mrFKFyBACL1xFJMlUVmgNvYN5S_txpeQPkz4LQ&type=album',
#         'type': 'm',
#         'width': 104},
#        {'height': 604,
#         'url': 'https://sun6-23.userapi.com/impg/PmK3iDWVrGaMuG800Lsq6t9L_SmlqfbwC0eAUQ/AQn5av6NpBU.jpg?size=483x604&quality=95&sign=3ac68846d1d036f14cedd7ba71f4c223&c_uniq_tag=w1J3rGIMnghv0hBq9Lp6LdRk_B9aHumPJdwmmy5TVO8&type=album',
#         'type': 'x',
#         'width': 483},
#        {'height': 807,
#         'url': 'https://sun6-23.userapi.com/impg/PmK3iDWVrGaMuG800Lsq6t9L_SmlqfbwC0eAUQ/AQn5av6NpBU.jpg?size=646x807&quality=95&sign=517b4430d1dae1dbae4e70f7570697fa&c_uniq_tag=Ffbgp9UTfnNZ_TF27vOUzgoosK_VmWzemlI8mhWdfbQ&type=album',
#         'type': 'y',
#         'width': 646},
#        {'height': 1080,
#         'url': 'https://sun6-23.userapi.com/impg/PmK3iDWVrGaMuG800Lsq6t9L_SmlqfbwC0eAUQ/AQn5av6NpBU.jpg?size=864x1080&quality=95&sign=d2b69e1f5e5ac969b18a2b204764d7aa&c_uniq_tag=HKR0Nj6GxoPzkwTFb2haLXuprsjL28nNFkdlTlozxx4&type=album',
#         'type': 'z',
#         'width': 864},
#        {'height': 1350,
#         'url': 'https://sun6-23.userapi.com/impg/PmK3iDWVrGaMuG800Lsq6t9L_SmlqfbwC0eAUQ/AQn5av6NpBU.jpg?size=1080x1350&quality=95&sign=244b8c2b27caf3bdb708b125c1996c79&c_uniq_tag=tRghyAOcv5oDVPaqPvScyGxY0t_pF3O0EFopkSP6bWU&type=album',
#         'type': 'w',
#         'width': 1080},
#        {'height': 162,
#         'url': 'https://sun6-23.userapi.com/impg/PmK3iDWVrGaMuG800Lsq6t9L_SmlqfbwC0eAUQ/AQn5av6NpBU.jpg?size=130x162&quality=95&sign=ac7e8961ba928f0af5095d1f567b9b53&c_uniq_tag=MsOsnqzkLhiQsLL_x9rv8GdAZksO1sSu3yImP_fuIZE&type=album',
#         'type': 'o',
#         'width': 130},
#        {'height': 250,
#         'url': 'https://sun6-23.userapi.com/impg/PmK3iDWVrGaMuG800Lsq6t9L_SmlqfbwC0eAUQ/AQn5av6NpBU.jpg?size=200x250&quality=95&sign=197e85d432b5ce79bc8998de2a2c0e15&c_uniq_tag=nMsVQB8RGlVCI8XYX_1V5x79b-T2-QgdhWdkBVZ4738&type=album',
#         'type': 'p',
#         'width': 200},
#        {'height': 400,
#         'url': 'https://sun6-23.userapi.com/impg/PmK3iDWVrGaMuG800Lsq6t9L_SmlqfbwC0eAUQ/AQn5av6NpBU.jpg?size=320x400&quality=95&sign=9885b1c2d0197f09d51b47ed4c8f3faa&c_uniq_tag=_rDb6Trv92Q_QJajgL3h11r1PXrYfuesMvIdTb-Eesc&type=album',
#         'type': 'q',
#         'width': 320},
#        {'height': 637,
#         'url': 'https://sun6-23.userapi.com/impg/PmK3iDWVrGaMuG800Lsq6t9L_SmlqfbwC0eAUQ/AQn5av6NpBU.jpg?size=510x637&quality=95&sign=bd72c53662bcb3415b20fc4548b90766&c_uniq_tag=zltlvfC3CL17Z7US2WGwGsc1QgJqkdhxQIYKZXQaaD8&type=album',
#         'type': 'r',
#         'width': 510}],
#       'text': '',
#       'user_id': 100,
#       'has_tags': False}},
#     {'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1665084338,
#       'id': 457974181,
#       'owner_id': -32370614,
#       'access_key': '06b40cdecaef4ebbec',
#       'sizes': [{'height': 75,
#         'url': 'https://sun6-20.userapi.com/impg/VpU2qJzAatGvr2z_CMce50bRLMWKfH7XvYzyBQ/N0xfri5oeBE.jpg?size=60x75&quality=95&sign=29b4dbc81ad272d0aa9a1bc1e7509474&c_uniq_tag=UcVJxM-UWGyGE6FIY4hMwP6POnUk7eKFGPlQOutUDQI&type=album',
#         'type': 's',
#         'width': 60},
#        {'height': 130,
#         'url': 'https://sun6-20.userapi.com/impg/VpU2qJzAatGvr2z_CMce50bRLMWKfH7XvYzyBQ/N0xfri5oeBE.jpg?size=104x130&quality=95&sign=874448fb33f9eb8a7aa8355905f89605&c_uniq_tag=QVRPPLz8gp_3SViu2OhcywKrJfFgFrtIf8t4Z8368Vo&type=album',
#         'type': 'm',
#         'width': 104},
#        {'height': 604,
#         'url': 'https://sun6-20.userapi.com/impg/VpU2qJzAatGvr2z_CMce50bRLMWKfH7XvYzyBQ/N0xfri5oeBE.jpg?size=483x604&quality=95&sign=bb0566067b6c3b4a3a30b6cfc6144be6&c_uniq_tag=ZpBtFzpQ8zQPxOhRE9z1zMek8iXmcf0m8Dl6GiKViQ4&type=album',
#         'type': 'x',
#         'width': 483},
#        {'height': 807,
#         'url': 'https://sun6-20.userapi.com/impg/VpU2qJzAatGvr2z_CMce50bRLMWKfH7XvYzyBQ/N0xfri5oeBE.jpg?size=646x807&quality=95&sign=6df6d6538d2ffdd409933000b55bbb6d&c_uniq_tag=pt9sKLT_8XFjjPKfINxlqrcuMlLPhEUbjORNTy9RBxI&type=album',
#         'type': 'y',
#         'width': 646},
#        {'height': 1080,
#         'url': 'https://sun6-20.userapi.com/impg/VpU2qJzAatGvr2z_CMce50bRLMWKfH7XvYzyBQ/N0xfri5oeBE.jpg?size=864x1080&quality=95&sign=857a01d785f16cd6bc2393d6faacdadc&c_uniq_tag=b_O_cqYSy7ONSCSvaAaP293Cqu4FQKTLZ_gTwM1anz4&type=album',
#         'type': 'z',
#         'width': 864},
#        {'height': 1350,
#         'url': 'https://sun6-20.userapi.com/impg/VpU2qJzAatGvr2z_CMce50bRLMWKfH7XvYzyBQ/N0xfri5oeBE.jpg?size=1080x1350&quality=95&sign=cef1da126f0bb6c446baf7240fea201c&c_uniq_tag=Jm6pV_DW-kK39WkT5n6daKnIYTevSSHQYnUqogYkVeI&type=album',
#         'type': 'w',
#         'width': 1080},
#        {'height': 162,
#         'url': 'https://sun6-20.userapi.com/impg/VpU2qJzAatGvr2z_CMce50bRLMWKfH7XvYzyBQ/N0xfri5oeBE.jpg?size=130x162&quality=95&sign=5fa86399ea1e32aa87859d5f3a8e13c6&c_uniq_tag=sHaSbwMMOaezrZIgj_m3b11ubLy6XvmZuRRKqCp8XuA&type=album',
#         'type': 'o',
#         'width': 130},
#        {'height': 250,
#         'url': 'https://sun6-20.userapi.com/impg/VpU2qJzAatGvr2z_CMce50bRLMWKfH7XvYzyBQ/N0xfri5oeBE.jpg?size=200x250&quality=95&sign=32936fa87a146b09ed27c43d9a77621e&c_uniq_tag=Y89ZLvNPH4NN8CPAPzbsFy8KY3U6PKCYB38GtPONTuA&type=album',
#         'type': 'p',
#         'width': 200},
#        {'height': 400,
#         'url': 'https://sun6-20.userapi.com/impg/VpU2qJzAatGvr2z_CMce50bRLMWKfH7XvYzyBQ/N0xfri5oeBE.jpg?size=320x400&quality=95&sign=0a19091009bc74a1f7d95f859de6c8e8&c_uniq_tag=_jyXlUhnfqbR9NMuojEKP6_Ju4F5FSPBYxp_cDVRsx8&type=album',
#         'type': 'q',
#         'width': 320},
#        {'height': 637,
#         'url': 'https://sun6-20.userapi.com/impg/VpU2qJzAatGvr2z_CMce50bRLMWKfH7XvYzyBQ/N0xfri5oeBE.jpg?size=510x637&quality=95&sign=46c81f7ed588a5a141bd741122abe634&c_uniq_tag=a7hSKWHZJ9RRwWyziurIgvHJIQJWk7vQ9Lhz_6XyxJ0&type=album',
#         'type': 'r',
#         'width': 510}],
#       'text': '',
#       'user_id': 100,
#       'has_tags': False}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'can_post': 1, 'count': 164, 'groups_can_post': True},
#    'likes': {'can_like': 1, 'count': 2615, 'user_likes': 0, 'can_publish': 1},
#    'reposts': {'count': 55, 'user_reposted': 0},
#    'views': {'count': 175966},
#    'donut': {'is_donut': False},
#    'short_text_rate': 0.8,
#    'carousel_offset': 0,
#    'hash': '897U1sIu24UAYB6J9LScUJQuxLk'}]}

# %%
ALL_COUNT = data['count']

# %%
ALL_COUNT
# Out:
# 48380

# %%
likes = [item['likes']['count'] for item in data['items']]

# %% [markdown]
# За один запрос скачалось всего-лишь $100$ постов с лайками. В паблике их целых
#
# [Документация](https://vk.com/dev/manuals) говорит, что есть параметр `offset`, с помощью которого можно указать какие именно посты из группы нужно скачать. Например, если мы укажем `offset = 100`, скачается вторая сотня. Наше дело за малым: написать цикл.

# %%
from tqdm import tqdm_notebook
import time

all_likes = []

for offset in tqdm_notebook(range(0, 1500 + 1, 100)):
    
    time.sleep(0.4) # вк согласен работать 3 раза в секунду, 
                    # между запросами python спит 0.4 секунды
    
    params = {
        'owner_id': -32370614,
        'count': 100,
        'offset': offset,
    }

    data = vk_api(
        method='wall.get',
        params=params,
    )
    
    likes = [item['likes']['count'] for item in data['items']]
    
    all_likes.extend(likes)
# Out:
# /var/folders/gt/9x_fxw4j5p5dvtl6519t2d700000gp/T/ipykernel_12827/4192623394.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for offset in tqdm_notebook(range(0, 1500 + 1, 100)):
#   0%|          | 0/16 [00:00<?, ?it/s]

# %%
len(all_likes)
# Out:
# 1600

# %%
import matplotlib.pyplot as plt 
plt.hist(all_likes);

# %% [markdown]
# ## Selenium

# %% [markdown]
# ### Selenium
#
# Веб-страницы бывают динамичные. Например, чтобы получить новую пачку товаров, нужно пролистать страницу вниз, тогда в html попадут новые товары. Или в ссылке страницы нет номера страницы, на которой мы находимся, зато есть кнопка "Следующая страница".
#
# Все это делает парсинг сложнее и обычного способа, которым мы пользовались раньше, уже недостаточно. Здесь нам может помочь **selenium**. **Selenium** – это инструмент для роботизированного управления браузером.
#
# Для его коректной работы нужно:
# 1. скачать драйвер: [для chrome](https://sites.google.com/chromium.org/driver/) или [для firefox](https://github.com/mozilla/geckodriver/releases)
# 2. установить пакет `pip install selenium`
#
# **Важно:** драйверы делаются для определенной версии браузера, поэтом проверьте главную версию своего бразуера (*Help -> About Google Chrome*) и скачайте драйвер для него.
#
# <img src="images/chrome_version.png" width="400px">

# %% [markdown]
# ### Инициализация сессии
#
# При создании сессии, нужно, чтобы *selenium* нашел драйвер, который мы скачали. Путь до драйвера можно указать явно или закинуть драйвер в системную папку с бинарниками. На маке: */usr/bin*.
#
# Если все получилось, то у вас откроется пустое окно браузера.

# %%
from selenium import webdriver

driver = webdriver.Chrome(
    '/Users/akhmed.zarmanbetov/Desktop/chromedriver',
)
# driver = webdriver.Firefox()
print(type(driver))
# Out:
# /var/folders/gt/9x_fxw4j5p5dvtl6519t2d700000gp/T/ipykernel_12827/2448612061.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(
# <class 'selenium.webdriver.chrome.webdriver.WebDriver'>

# %%
# если драйвер лежит с бинарниками
from selenium import webdriver

driver = webdriver.Chrome()
# driver = webdriver.Firefox()
print(type(driver))

# %% [markdown]
# ### Переход на страницу
#
# После того как браузер запущен вы будете использовать разные методы у объекта `driver`. Первый метод, который вам нужен `.get`, который принимает *url* и переходит на страницу.

# %%
ref = 'https://www.wildberries.ru/'
# ref = 'https://www.ozon.ru/'
driver.get(ref)

# %% [markdown]
# <img src="images/wb_main.png">

# %% [markdown]
# ### Поисковая строка
#
# Допустим, мы хотим найти товары по запросу. Для этого нам нужно вбить их в поисковую строку. Сначала найдем элемент, а дальше можем на него кликнуть.

# %%
from selenium.webdriver.common.by import By

search = driver.find_element(
    by=By.ID,
    value='searchInput',
)

search.click()

# %% [markdown]
# <img src="images/wb_search.png">

# %% [markdown]
# ### Запрос
#
# Теперь в эту поисковую строку нужно что-то записать и нажать *Enter*.

# %%
from selenium.webdriver.common.keys import Keys

search.send_keys('футболка мужская')
search.send_keys(Keys.ENTER)

# search.clear()  # очищает строку

# %% [markdown]
# <img src="images/wb_find.png">

# %% [markdown]
# ### Дальше уже умеем
#
# Дальше мы можем получить *html* и искать в нем. Надо только закрыть браузер.

# %%
from bs4 import BeautifulSoup

bs = BeautifulSoup(driver.page_source)

driver.close()

# %% [markdown]
# ### Полезные ссылки
#
# Вообще *selenium* придумывали для тестировщиков, а не для парсинга. Для парсеров имеет смысл использовать только в крайнем случае. Он очень медленный.
#
# [Документация](https://selenium-python.readthedocs.io) selenium.
#
# [Решение](https://stackoverflow.com/questions/15058462/how-to-save-and-load-cookies-using-python-selenium-webdriver/15058521#15058521) как сохранять куки.
#
# [Решение](https://stackoverflow.com/questions/29916054/change-user-agent-for-selenium-web-driver) как поменять *User-Agent*. По дефолту у *selenium* он нормальный. Можно посмотреть с помощью команды:
# ```
# agent = driver.execute_script("return navigator.userAgent")
# ```
#
# [Waiting](https://selenium-python.readthedocs.io/waits.html) – умное ожидание загрузки страницы.
#
# [Scrolling](https://stackoverflow.com/questions/20986631/how-can-i-scroll-a-web-page-using-selenium-webdriver-in-python) – как листать страницу вверх-вниз.
#
# ```python
# driver.forward()
# driver.back()
# ```

# %% [markdown]
# ## Хитрости

# %% [markdown]
# ### Хитрость №1:  не стесняйтесь пользоваться `try-except`
#
# __Как это использовать при парсинге?__
# Предположим, что мы на ночь поставили парсер скачивать цены, он отработал час и упал из-за того, что на какой-нибудь одной странице были криво проставлены теги, либо вылезло какое-то редкое поле, либо вылезли какие-то артефакты от старой версии сайта, которые не были учтены в нашем парсере. Гораздо лучше, чтобы код проигнорировал эту ошибку и продолжил работать дальше. Можно даже складывать плохие ссылки, чтобы отсмотреть их потом и перезапустить позже.

# %%
from math import log

x = [10, 5, 13, -5, 12]
y = []

for num in x:
    try:
        y.append(log(num))
    except:
        continue

# %%
x
# Out:
# [10, 5, 13, -5, 12]

# %%
y
# Out:
# [2.302585092994046, 1.6094379124341003, 2.5649493574615367, 2.4849066497880004]

# %%
bad_urls = []
data = {}
for url in urls:
    try:
        data[url] = parse_data(url)
    except:
        print(f'Плохая ссылка: {url}')
        bad_urls.append(url)

# %% [markdown]
# ### Хитрость №2: pd.read_html
#
# Если на странице, которую вы спарсили, среди тэгов `<tr>` и `<td>` прячется таблица, чаще всего можно забрать её себе без написания цикла, который будет перебирать все стобцы и строки. Поможет в этом `pd.read_html`. Например, вот так можно забрать себе [табличку с сайта ЦБ](https://cbr.ru/currency_base/daily/)

# %%
import pandas as pd

df = pd.read_html('https://cbr.ru/currency_base/daily/')[0]
df.head()
# Out:
#    Цифр. код Букв. код  Единиц                 Валюта    Курс
# 0         36       AUD       1   Австралийский доллар  399813
# 1        944       AZN       1  Азербайджанский манат  375035
# 2         51       AMD     100       Армянских драмов  157917
# 3        933       BYN       1      Белорусский рубль  246829
# 4        975       BGN       1         Болгарский лев  316941

# %% [markdown]
# ### Хитрость №3:  используйте пакет tqdm
#
# > Код уже работает час. Я вообще без понятия когда он закончит работу. Было бы круто узнать, сколько ещё ждать...
#
# Если в вашей голове возникла такая мысль, пакет `tqdm` ваш лучший друг. Установите его: ```pip install tqdm```.

# %%
import time
from tqdm import tqdm_notebook

a = list(range(30))

for i in tqdm_notebook(a):
    time.sleep(1)
# Out:
# /var/folders/8m/23gw8hwj6yz374j_gh302xhc0000gp/T/ipykernel_3240/1482089762.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(a):
#   0%|          | 0/30 [00:00<?, ?it/s]

# %% [markdown]
# ### Хитрость №4:  распаралеливание
#
# Если сервер не очень настроен вас банить, можно распаралелить свои запросы к нему. Самый простой способ сделать это — библиотека `joblib`. Или библиотека `multiprocessing`.

# %%
# !pip install joblib
from joblib import Parallel, delayed
from tqdm import tqdm_notebook

def simple_function(x):
    return x**2


nj = -1 # паралель на все ядра 
result = Parallel(n_jobs=nj)(
                delayed(simple_function)(item)          # какую функцию применяем 
                for item in tqdm_notebook(range(10)))   # к каким объектам применям
# Out:
# /var/folders/8m/23gw8hwj6yz374j_gh302xhc0000gp/T/ipykernel_3240/2388287161.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for item in tqdm_notebook(range(10)))   # к каким объектам применям
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ### Хитрость №5:  selenium без браузера
#
# *Selenium* можно настроить так, чтобы физически браузер не открывался. Удобно, когда вы уже все настроили.

# %%
from selenium import webdriver
from selenium.webdriver.firefox.options import Options

options = Options()
options.headless = True 
driver = webdriver.Firefox(options=options)

ref = 'http://google.com'
driver.get(ref)

driver.close()

# %% [markdown]
# ### Ещё хитрости
#
# * __Сохраняйте то, что парсите по мере скачки!__ Прямо внутрь цикла напишите код, который сохраняет данные в файл. Лучше сохранять батчами.
# * Когда код упал в середине списка для скачки, не обязательно запускать его с самого начала. Просто сохраните тот кусок, который уже скачался и дозапустите код с места падения.
# * Можно ориентироваться на html-страничке с помощью `xpath`. Он предназначен для того, чтобы внутри html-странички можно было быстро находить какие-то элементы. [Подробнее можно почитать тут](https://devhints.io/xpath).
# * Не ленитесь листать документацию. Из неё можно узнать много полезных штук.
